# %% [markdown]
# <a href="https://colab.research.google.com/github/Andres14Reinaldo/IA_USTA/blob/main/FUZZY/S1_C2_Fuzzy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # Instalando la librería

# %%
# !pip install scikit-fuzzy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.8/920.8 kB 26.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Importando librerías

# %%
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Ejercicio 1: Graficar variable de Temperatura

# %%
Temperatura = ctrl.Antecedent(np.arange(80, 110, 1), 'Temperatura')
Temperatura['High'] = fuzz.trapmf(Temperatura.universe, [80, 80, 90, 100])
Temperatura['High High'] = fuzz.trapmf(Temperatura.universe, [90, 100, 110, 110])

Temperatura.view()

# %% [markdown]
# #Ejercicio 2 : Tres funciones de pertenencia

# %%
Temperatura = ctrl.Antecedent(np.arange(60, 110, 1), 'Temperatura')
Temperatura['Medio'] = fuzz.trapmf(Temperatura.universe, [60, 60, 70, 80])
Temperatura['Alto'] = fuzz.trapmf(Temperatura.universe, [70, 80, 90, 100])
Temperatura['Muy Alto'] = fuzz.trapmf(Temperatura.universe, [90, 100, 110, 110])

Temperatura.view()
